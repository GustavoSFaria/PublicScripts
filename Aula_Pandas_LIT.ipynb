# %% [markdown]
# <a href="https://colab.research.google.com/github/GustavoSFaria/PublicScripts/blob/main/Aula_Pandas_LIT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <font color=green> Pandas para Data Science

# %%
import pandas as pd

# %%
# criando um vetor de números inteiros.
# OBS: a função mean() para calcular a média não funciona para vetores. Precisa antes transformar o objeto em "Series" ou "DataFrame" do Pandas
notas = [10, 20, 30, 40]
type(notas)
# Out:
# list

# %%
# transformando o objeto notas em uma "Series" do Pandas
notas = pd.Series(notas)
type(notas)
# Out:
# pandas.core.series.Series

# %%
# exibindo o obejeto como "Series" do Pandas
notas
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
# Através de uma "Series" ou "DataFrame" do Pandas é possível utilizar a função mean() para calcular a média.
notas.mean()
# Out:
# 25.0

# %%
# transformando o objeto notas em um "DataFrame" do Pandas
notas = pd.DataFrame(notas)
type(notas)
# Out:
# pandas.core.frame.DataFrame

# %%
# exibindo o obejeto como "Dataframe" do Pandas (o layout de exibição do DataFrame é diferente do layout de uma Series)
notas
# Out:
#     0
# 0  10
# 1  20
# 2  30
# 3  40

# %%
# criando um DataFrame a partir de uma lista de dicionários
dados = [
    {'Nome': 'Jetta Variant', 'Motor': 'Motor 4.0 Turbo', 'Ano': 2003, 'Quilometragem': 44410.0, 'Zero_km': False, 'Valor': 88078.64},
    {'Nome': 'Passat', 'Motor': 'Motor Diesel', 'Ano': 1991, 'Quilometragem': 5712.0, 'Zero_km': False, 'Valor': 106161.94},
    {'Nome': 'Crossfox', 'Motor': 'Motor Diesel V8', 'Ano': 1990, 'Quilometragem': 37123.0, 'Zero_km': False, 'Valor': 72832.16}
]
df = pd.DataFrame(dados)
df
# Out:
#             Nome            Motor   Ano  Quilometragem  Zero_km      Valor
# 0  Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False   88078.64
# 1         Passat     Motor Diesel  1991         5712.0    False  106161.94
# 2       Crossfox  Motor Diesel V8  1990        37123.0    False   72832.16

# %%
# criando um DataFrame a partir de um dicionário de listas
dados = {
    'Nome': ['Jetta Variant', 'Passat', 'Crossfox'], 
    'Motor': ['Motor 4.0 Turbo', 'Motor Diesel', 'Motor Diesel V8'],
    'Ano': [2003, 1991, 1990],
    'Quilometragem': [44410.0, 5712.0, 37123.0],
    'Zero_km': [False, False, False],
    'Valor': [88078.64, 106161.94, 72832.16]
}
df = pd.DataFrame(dados)
df
# Out:
#             Nome            Motor   Ano  Quilometragem  Zero_km      Valor
# 0  Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False   88078.64
# 1         Passat     Motor Diesel  1991         5712.0    False  106161.94
# 2       Crossfox  Motor Diesel V8  1990        37123.0    False   72832.16

# %%
# selecionando uma coluna no DataFrame. O resultado será uma "Series" do Pandas
coluna = df['Valor']
coluna
# Out:
# 0     88078.64
# 1    106161.94
# 2     72832.16
# Name: Valor, dtype: float64

# %%
type(coluna)
# Out:
# pandas.core.series.Series

# %%
# selecionando uma coluna no DataFrame. Quando utilizamos dois colchetes, o resultado será um "DataFrame" do Pandas
# os dois colchetes [[]] é um "atalho" para a criação de DataFrame
coluna = df[['Valor']]
coluna
# Out:
#        Valor
# 0   88078.64
# 1  106161.94
# 2   72832.16

# %%
type(coluna)
# Out:
# pandas.core.frame.DataFrame

# %%
# carregando o conjunto de dados "carro.csv" que está armazenado no GitHub
dataset = pd.read_csv('https://raw.githubusercontent.com/GustavoSFaria/PublicDatasets/main/carros.csv', sep=';')
dataset
# Out:
#                       Nome                  Motor   Ano  Quilometragem  \
# 0            Jetta Variant        Motor 4.0 Turbo  2003        44410.0
# 1                   Passat           Motor Diesel  1991         5712.0
# 2                 Crossfox        Motor Diesel V8  1990        37123.0
# 3                      DS5        Motor 2.4 Turbo  2019            NaN
# 4         Aston Martin DB4        Motor 2.4 Turbo  2006        25757.0
# ..                     ...                    ...   ...            ...
# 253           Phantom 2013               Motor V8  2014        27505.0
# 254  Cadillac Ciel concept               Motor V8  1991        29981.0
# 255             Classe GLK  Motor 5.0 V8 Bi-Turbo  2002        52637.0
# 256       Aston Martin DB5           Motor Diesel  1996         7685.0
# 257                  Macan        Motor Diesel V6  1992        50188.0
#
#      Zero_km                                         Acessórios      Valor
# ...

# %%
# verificando o tipo do objeto "dataset"
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
# verificando os tipos de dados das colunas
dataset.dtypes
# Out:
# Nome              object
# Motor             object
# Ano                int64
# Quilometragem    float64
# Zero_km             bool
# Acessórios        object
# Valor            float64
# dtype: object

# %%
# verificando as primeiras linhas
dataset.head()
# Out:
#                Nome            Motor   Ano  Quilometragem  Zero_km  \
# 0     Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False
# 1            Passat     Motor Diesel  1991         5712.0    False
# 2          Crossfox  Motor Diesel V8  1990        37123.0    False
# 3               DS5  Motor 2.4 Turbo  2019            NaN     True
# 4  Aston Martin DB4  Motor 2.4 Turbo  2006        25757.0    False
#
#                                           Acessórios      Valor
# 0  ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# 1  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# 2  ['Piloto automático', 'Controle de estabilidad...   72832.16
# 3  ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07
# 4  ['Rodas de liga', '4 X 4', 'Central multimídia...   92612.10

# %%
# verificando informações do dataset
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258 entries, 0 to 257
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Nome           258 non-null    object
#  1   Motor          258 non-null    object
#  2   Ano            258 non-null    int64
#  3   Quilometragem  197 non-null    float64
#  4   Zero_km        258 non-null    bool
#  5   Acessórios     258 non-null    object
#  6   Valor          258 non-null    float64
# dtypes: bool(1), float64(2), int64(1), object(3)
# memory usage: 12.5+ KB

# %%
# verificando a média da coluna "valor" do dataset
dataset['Valor'].mean()
# Out:
# 98960.51310077519

# %%
# verificando as estatísticas da coluna "valor" do dataset
dataset['Valor'].describe()
# Out:
# count       258.000000
# mean      98960.513101
# std       29811.932305
# min       50742.100000
# 25%       70743.512500
# 50%       97724.380000
# 75%      124633.302500
# max      149489.920000
# Name: Valor, dtype: float64

# %%
# selecionando os dois primeiros valores (linhas)
dataset['Valor'][0:2]
# Out:
# 0     88078.64
# 1    106161.94
# Name: Valor, dtype: float64

# %%
# verificando as colunas do dataset
dataset.columns
# Out:
# Index(['Nome', 'Motor', 'Ano', 'Quilometragem', 'Zero_km', 'Acessórios',
#        'Valor'],
#       dtype='object')

# %%
# aplicando um filtro no dataset utilizando uma lista com colunas selecionadas
filtro = ['Nome','Valor']
subset = dataset[filtro]
subset
# Out:
#                       Nome      Valor
# 0            Jetta Variant   88078.64
# 1                   Passat  106161.94
# 2                 Crossfox   72832.16
# 3                      DS5  124549.07
# 4         Aston Martin DB4   92612.10
# ..                     ...        ...
# 253           Phantom 2013   51759.58
# 254  Cadillac Ciel concept   51667.06
# 255             Classe GLK   68934.03
# 256       Aston Martin DB5  122110.90
# 257                  Macan   90381.47
#
# [258 rows x 2 columns]

# %%
# carregando o conjunto de dados "carro.csv" novavemnete, considerando a primeira coluna como índice (é possível considerar outras colunas)
dataset = pd.read_csv('https://raw.githubusercontent.com/GustavoSFaria/PublicDatasets/main/carros.csv', sep=';', index_col=0)
dataset
# Out:
#                                        Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Jetta Variant                Motor 4.0 Turbo  2003        44410.0    False
# Passat                          Motor Diesel  1991         5712.0    False
# Crossfox                     Motor Diesel V8  1990        37123.0    False
# DS5                          Motor 2.4 Turbo  2019            NaN     True
# Aston Martin DB4             Motor 2.4 Turbo  2006        25757.0    False
# ...                                      ...   ...            ...      ...
# Phantom 2013                        Motor V8  2014        27505.0    False
# Cadillac Ciel concept               Motor V8  1991        29981.0    False
# Classe GLK             Motor 5.0 V8 Bi-Turbo  2002        52637.0    False
# Aston Martin DB5                Motor Diesel  1996         7685.0    False
# Macan                        Motor Diesel V6  1992        50188.0    False
#
# ...

# %%
# selecionando uma coluna
dataset['Valor']
# Out:
# Nome
# Jetta Variant             88078.64
# Passat                   106161.94
# Crossfox                  72832.16
# DS5                      124549.07
# Aston Martin DB4          92612.10
#                            ...
# Phantom 2013              51759.58
# Cadillac Ciel concept     51667.06
# Classe GLK                68934.03
# Aston Martin DB5         122110.90
# Macan                     90381.47
# Name: Valor, Length: 258, dtype: float64

# %%
# selecionando linhas [i:j]
dataset[0:3]
# Out:
#                          Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False
# Passat            Motor Diesel  1991         5712.0    False
# Crossfox       Motor Diesel V8  1990        37123.0    False
#
#                                                       Acessórios      Valor
# Nome
# Jetta Variant  ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# Passat         ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# Crossfox       ['Piloto automático', 'Controle de estabilidad...   72832.16

# %% [markdown]
# ## Utilizando .loc e .iloc

# %%
# selecionando linha com "loc". loc = [[linhas],[colunas]]
# obs1: Por ter transformado a primeira coluna em índice é que torna-se possível utilizar os nomes dos veículos no "loc", senão seria o número dos índices
# obs2: as duas chaves é para exibir o objeto como DataFrame.
dataset.loc[['Passat']]
# Out:
#                Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Passat  Motor Diesel  1991         5712.0    False
#
#                                                Acessórios      Valor
# Nome
# Passat  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94

# %%
# selecionando linhas com "loc".
# obs: as duas chaves é para exibir o objeto como DataFrame
dataset.loc[['Passat', 'Macan']]
# Out:
#                   Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Passat     Motor Diesel  1991         5712.0    False
# Macan   Motor Diesel V6  1992        50188.0    False
#
#                                                Acessórios      Valor
# Nome
# Passat  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# Macan   ['Central multimídia', 'Teto panorâmico', 'Vid...   90381.47

# %%
#selecionando linhas e colunas com loc. loc = [[linhas],[colunas]]
dataset.loc[['Passat', 'Macan'],['Motor','Valor']]
# Out:
#                   Motor      Valor
# Nome
# Passat     Motor Diesel  106161.94
# Macan   Motor Diesel V6   90381.47

# %%
# selecionando todas as linhas e apenas duas colunas
dataset.loc[:,['Motor','Valor']]
# Out:
#                                        Motor      Valor
# Nome
# Jetta Variant                Motor 4.0 Turbo   88078.64
# Passat                          Motor Diesel  106161.94
# Crossfox                     Motor Diesel V8   72832.16
# DS5                          Motor 2.4 Turbo  124549.07
# Aston Martin DB4             Motor 2.4 Turbo   92612.10
# ...                                      ...        ...
# Phantom 2013                        Motor V8   51759.58
# Cadillac Ciel concept               Motor V8   51667.06
# Classe GLK             Motor 5.0 V8 Bi-Turbo   68934.03
# Aston Martin DB5                Motor Diesel  122110.90
# Macan                        Motor Diesel V6   90381.47
#
# [258 rows x 2 columns]

# %%
dataset.head()
# Out:
#                             Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Jetta Variant     Motor 4.0 Turbo  2003        44410.0    False
# Passat               Motor Diesel  1991         5712.0    False
# Crossfox          Motor Diesel V8  1990        37123.0    False
# DS5               Motor 2.4 Turbo  2019            NaN     True
# Aston Martin DB4  Motor 2.4 Turbo  2006        25757.0    False
#
#                                                          Acessórios      Valor
# Nome
# Jetta Variant     ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# Passat            ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# Crossfox          ['Piloto automático', 'Controle de estabilidad...   72832.16
# DS5               ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07
# Aston Martin DB4  ['Rodas de liga', '4 X 4', 'Central multimídia...   92612.10

# %%
# selecionando linhas e colunas com iloc (utiliza os índices das linhas e colunas)
dataset.iloc[[0]]
# Out:
#                          Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False
#
#                                                       Acessórios     Valor
# Nome
# Jetta Variant  ['Rodas de liga', 'Travas elétricas', 'Piloto ...  88078.64

# %%
dataset.iloc[[0,3],[0,2]]
# Out:
#                          Motor  Quilometragem
# Nome
# Jetta Variant  Motor 4.0 Turbo        44410.0
# DS5            Motor 2.4 Turbo            NaN

# %%
dataset.iloc[0:3,0:2]
# Out:
#                          Motor   Ano
# Nome
# Jetta Variant  Motor 4.0 Turbo  2003
# Passat            Motor Diesel  1991
# Crossfox       Motor Diesel V8  1990

# %%
# selecionando 3 colunas e alterando a ordem das colunas
dataset.iloc[:,[2,0,1]]
# Out:
#                        Quilometragem                  Motor   Ano
# Nome
# Jetta Variant                44410.0        Motor 4.0 Turbo  2003
# Passat                        5712.0           Motor Diesel  1991
# Crossfox                     37123.0        Motor Diesel V8  1990
# DS5                              NaN        Motor 2.4 Turbo  2019
# Aston Martin DB4             25757.0        Motor 2.4 Turbo  2006
# ...                              ...                    ...   ...
# Phantom 2013                 27505.0               Motor V8  2014
# Cadillac Ciel concept        29981.0               Motor V8  1991
# Classe GLK                   52637.0  Motor 5.0 V8 Bi-Turbo  2002
# Aston Martin DB5              7685.0           Motor Diesel  1996
# Macan                        50188.0        Motor Diesel V6  1992
#
# [258 rows x 3 columns]

# %% [markdown]
# ## Queries com DataFrames

# %%
# dataset.Motor é igual a dataset['Motor']
dataset.Motor
# Out:
# Nome
# Jetta Variant                  Motor 4.0 Turbo
# Passat                            Motor Diesel
# Crossfox                       Motor Diesel V8
# DS5                            Motor 2.4 Turbo
# Aston Martin DB4               Motor 2.4 Turbo
#                                  ...
# Phantom 2013                          Motor V8
# Cadillac Ciel concept                 Motor V8
# Classe GLK               Motor 5.0 V8 Bi-Turbo
# Aston Martin DB5                  Motor Diesel
# Macan                          Motor Diesel V6
# Name: Motor, Length: 258, dtype: object

# %%
dataset.Motor == 'Motor V8'
# Out:
# Nome
# Jetta Variant            False
# Passat                   False
# Crossfox                 False
# DS5                      False
# Aston Martin DB4         False
#                          ...
# Phantom 2013              True
# Cadillac Ciel concept     True
# Classe GLK               False
# Aston Martin DB5         False
# Macan                    False
# Name: Motor, Length: 258, dtype: bool

# %%
filtro = dataset.Motor == 'Motor V8'
dataset[filtro]
# Out:
#                                          Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Série 1 M                             Motor V8  2019            NaN     True
# J2                                    Motor V8  2014        90684.0    False
# Aston Martin DBS                      Motor V8  1995        43975.0    False
# Carnival                              Motor V8  2000        67716.0    False
# Accord                                Motor V8  2019            NaN     True
# Touareg                               Motor V8  2019            NaN     True
# Celer Hatch                           Motor V8  2008       113808.0    False
# HB20S                                 Motor V8  2008          610.0    False
# Face                                  Motor V8  2019            NaN     True
# Frontier                              Motor V8  2001        89056.0    False
# Aston Martin V8 Vantage               Motor V8  2017        10821.0    False
# ...

# %%
type(filtro)
# Out:
# pandas.core.series.Series

# %%
filtro2 = (dataset.Motor == 'Motor V8') & (dataset.Zero_km == True) & (dataset.Valor > 100000)
dataset[filtro2]
# Out:
#                              Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Accord                    Motor V8  2019            NaN     True
# Aston Martin V12 Vantage  Motor V8  2019            NaN     True
# Chana Family              Motor V8  2019            NaN     True
# Benni Mini                Motor V8  2019            NaN     True
#
#                                                                  Acessórios  \
# Nome
# Accord                    ['Sensor de estacionamento', 'Ar condicionado'...
# Aston Martin V12 Vantage  ['Bancos de couro', 'Central multimídia', 'Con...
# Chana Family              ['Piloto automático', 'Teto panorâmico', 'Sens...
# Benni Mini                ['Sensor crepuscular', 'Câmbio automático', 'C...
#
#                               Valor
# Nome
# Accord                    131961.43
# Aston Martin V12 Vantage  128396.11
# Chana Family              115760.17
# Benni Mini                126247.84

# %%
# fazendo filtros com o método Query
dataset.query('Motor == "Motor V8" and Zero_km == True and Valor > 100000')
# Out:
#                              Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Accord                    Motor V8  2019            NaN     True
# Aston Martin V12 Vantage  Motor V8  2019            NaN     True
# Chana Family              Motor V8  2019            NaN     True
# Benni Mini                Motor V8  2019            NaN     True
#
#                                                                  Acessórios  \
# Nome
# Accord                    ['Sensor de estacionamento', 'Ar condicionado'...
# Aston Martin V12 Vantage  ['Bancos de couro', 'Central multimídia', 'Con...
# Chana Family              ['Piloto automático', 'Teto panorâmico', 'Sens...
# Benni Mini                ['Sensor crepuscular', 'Câmbio automático', 'C...
#
#                               Valor
# Nome
# Accord                    131961.43
# Aston Martin V12 Vantage  128396.11
# Chana Family              115760.17
# Benni Mini                126247.84

# %% [markdown]
# ##Iterando com DataFrames

# %%
dataset.head()
# Out:
#                             Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Jetta Variant     Motor 4.0 Turbo  2003        44410.0    False
# Passat               Motor Diesel  1991         5712.0    False
# Crossfox          Motor Diesel V8  1990        37123.0    False
# DS5               Motor 2.4 Turbo  2019            NaN     True
# Aston Martin DB4  Motor 2.4 Turbo  2006        25757.0    False
#
#                                                          Acessórios      Valor
# Nome
# Jetta Variant     ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# Passat            ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# Crossfox          ['Piloto automático', 'Controle de estabilidad...   72832.16
# DS5               ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07
# Aston Martin DB4  ['Rodas de liga', '4 X 4', 'Central multimídia...   92612.10

# %%
# interando linha a linha sem utilizar o loop "for". O pacote Pandas oferece esta possibilidade nativa.
# incluindo a coluna km_medio = km/(ano atual/ano fabricação)

dataset['km_medio'] = (dataset.Quilometragem/(2022 - dataset.Ano))
dataset
# Out:
#                                        Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Jetta Variant                Motor 4.0 Turbo  2003        44410.0    False
# Passat                          Motor Diesel  1991         5712.0    False
# Crossfox                     Motor Diesel V8  1990        37123.0    False
# DS5                          Motor 2.4 Turbo  2019            NaN     True
# Aston Martin DB4             Motor 2.4 Turbo  2006        25757.0    False
# ...                                      ...   ...            ...      ...
# Phantom 2013                        Motor V8  2014        27505.0    False
# Cadillac Ciel concept               Motor V8  1991        29981.0    False
# Classe GLK             Motor 5.0 V8 Bi-Turbo  2002        52637.0    False
# Aston Martin DB5                Motor Diesel  1996         7685.0    False
# Macan                        Motor Diesel V6  1992        50188.0    False
#
# ...

# %%
# verificando quantos carros são Zero Quilômetro (nestes casos o km_nmedio foi calculado como NaN)
len(dataset.query('Zero_km == True'))
# Out:
# 61

# %%
# preenchendo os valores NaN para a coluna km_medio
dataset['km_medio'] = (dataset.Quilometragem/(2022 - dataset.Ano)).fillna(0)
dataset
# Out:
#                                        Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Jetta Variant                Motor 4.0 Turbo  2003        44410.0    False
# Passat                          Motor Diesel  1991         5712.0    False
# Crossfox                     Motor Diesel V8  1990        37123.0    False
# DS5                          Motor 2.4 Turbo  2019            NaN     True
# Aston Martin DB4             Motor 2.4 Turbo  2006        25757.0    False
# ...                                      ...   ...            ...      ...
# Phantom 2013                        Motor V8  2014        27505.0    False
# Cadillac Ciel concept               Motor V8  1991        29981.0    False
# Classe GLK             Motor 5.0 V8 Bi-Turbo  2002        52637.0    False
# Aston Martin DB5                Motor Diesel  1996         7685.0    False
# Macan                        Motor Diesel V6  1992        50188.0    False
#
# ...

# %% [markdown]
# ##Tratamento de Dados

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 258 entries, Jetta Variant to Macan
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Motor          258 non-null    object
#  1   Ano            258 non-null    int64
#  2   Quilometragem  197 non-null    float64
#  3   Zero_km        258 non-null    bool
#  4   Acessórios     258 non-null    object
#  5   Valor          258 non-null    float64
#  6   km_medio       258 non-null    float64
# dtypes: bool(1), float64(3), int64(1), object(2)
# memory usage: 22.5+ KB

# %%
# verificando dados faltante na coluna Quilomeragem
dataset['Quilometragem'].isna()
# Out:
# Nome
# Jetta Variant            False
# Passat                   False
# Crossfox                 False
# DS5                       True
# Aston Martin DB4         False
#                          ...
# Phantom 2013             False
# Cadillac Ciel concept    False
# Classe GLK               False
# Aston Martin DB5         False
# Macan                    False
# Name: Quilometragem, Length: 258, dtype: bool

# %%
# contando dados faltantes na coluna Quilomeragem
faltantes = dataset['Quilometragem'].isna()
faltantes.sum()
# Out:
# 61

# %%
# preenchendo dados faltanes com "0" na coluna Quilomeragem. Poderia ser um cálculo no lugar do "0"
dataset['Quilometragem'].fillna(0, inplace = True)
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 258 entries, Jetta Variant to Macan
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Motor          258 non-null    object
#  1   Ano            258 non-null    int64
#  2   Quilometragem  258 non-null    float64
#  3   Zero_km        258 non-null    bool
#  4   Acessórios     258 non-null    object
#  5   Valor          258 non-null    float64
#  6   km_medio       258 non-null    float64
# dtypes: bool(1), float64(3), int64(1), object(2)
# memory usage: 22.5+ KB

# %%
# carregando novamente o conjunto de dados original "carro.csv" que está armazenado no GitHub
dataset = pd.read_csv('https://raw.githubusercontent.com/GustavoSFaria/PublicDatasets/main/carros.csv', sep=';')
dataset
# Out:
#                       Nome                  Motor   Ano  Quilometragem  \
# 0            Jetta Variant        Motor 4.0 Turbo  2003        44410.0
# 1                   Passat           Motor Diesel  1991         5712.0
# 2                 Crossfox        Motor Diesel V8  1990        37123.0
# 3                      DS5        Motor 2.4 Turbo  2019            NaN
# 4         Aston Martin DB4        Motor 2.4 Turbo  2006        25757.0
# ..                     ...                    ...   ...            ...
# 253           Phantom 2013               Motor V8  2014        27505.0
# 254  Cadillac Ciel concept               Motor V8  1991        29981.0
# 255             Classe GLK  Motor 5.0 V8 Bi-Turbo  2002        52637.0
# 256       Aston Martin DB5           Motor Diesel  1996         7685.0
# 257                  Macan        Motor Diesel V6  1992        50188.0
#
#      Zero_km                                         Acessórios      Valor
# ...

# %%
# eliminando as linhas com dados ausentes nas colunas Quilometragem e Valor
dataset.dropna(subset = ['Quilometragem','Valor'], inplace = True)
dataset
# Out:
#                       Nome                  Motor   Ano  Quilometragem  \
# 0            Jetta Variant        Motor 4.0 Turbo  2003        44410.0
# 1                   Passat           Motor Diesel  1991         5712.0
# 2                 Crossfox        Motor Diesel V8  1990        37123.0
# 4         Aston Martin DB4        Motor 2.4 Turbo  2006        25757.0
# 5            Palio Weekend          Motor 1.8 16v  2012        10728.0
# ..                     ...                    ...   ...            ...
# 253           Phantom 2013               Motor V8  2014        27505.0
# 254  Cadillac Ciel concept               Motor V8  1991        29981.0
# 255             Classe GLK  Motor 5.0 V8 Bi-Turbo  2002        52637.0
# 256       Aston Martin DB5           Motor Diesel  1996         7685.0
# 257                  Macan        Motor Diesel V6  1992        50188.0
#
#      Zero_km                                         Acessórios      Valor
# ...

# %%
# classificando coluna em ordem crescente (ascending = True) ou decrescente (ascending = False)
dataset.sort_values(by = "Valor", ascending = True)
# Out:
#                       Nome            Motor   Ano  Quilometragem  Zero_km  \
# 254  Cadillac Ciel concept         Motor V8  1991        29981.0    False
# 253           Phantom 2013         Motor V8  2014        27505.0    False
# 82      Cadillac XTS sedan  Motor Diesel V6  1993        90924.0    False
# 199                    C30     Motor 1.0 8v  2001        55738.0    False
# 163                  Equus    Motor 3.0 32v  2004        57683.0    False
# ..                     ...              ...   ...            ...      ...
# 69          Kangoo Express     Motor Diesel  2007        29132.0    False
# 172                Boxster  Motor Diesel V8  2013        73914.0    False
# 125              C5 Tourer  Motor Diesel V6  1999        80187.0    False
# 50                   Versa    Motor 3.0 32v  2009        85554.0    False
# 128                    ASX  Motor Diesel V8  2003        61672.0    False
#
#                                             Acessórios      Valor
# ...

# %%
# agrupando os registros por motor e calculando o Valor Médio
dataset.groupby(by = "Motor")['Valor'].mean()
# Out:
# Motor
# Motor 1.0 8v              95741.644091
# Motor 1.8 16v             83965.033571
# Motor 2.0 16v             93863.430000
# Motor 2.4 Turbo           99625.485000
# Motor 3.0 32v             91108.872941
# Motor 4.0 Turbo          106434.262632
# Motor 5.0 V8 Bi-Turbo     86905.821765
# Motor Diesel             107459.729048
# Motor Diesel V6          102362.868333
# Motor Diesel V8          102782.106667
# Motor V6                 109737.689375
# Motor V8                  98423.970000
# Name: Valor, dtype: float64

# %%
# agrupando os registros por motor, verificando as estatísticas descritivas e ordenando por média
dataset.groupby(by = "Motor")['Valor'].describe().sort_values(by = "mean", ascending = True)
# Out:
#                        count           mean           std       min  \
# Motor
# Motor 1.8 16v           14.0   83965.033571  24304.445716  53894.61
# Motor 5.0 V8 Bi-Turbo   17.0   86905.821765  30820.888781  56208.70
# Motor 3.0 32v           17.0   91108.872941  29954.318591  53620.31
# Motor 2.0 16v           15.0   93863.430000  31659.384099  60813.92
# Motor 1.0 8v            22.0   95741.644091  31011.090298  52805.91
# Motor V8                17.0   98423.970000  34475.314391  51667.06
# Motor 2.4 Turbo          6.0   99625.485000  19108.328862  79782.02
# Motor Diesel V6         18.0  102362.868333  28298.101679  52207.45
# Motor Diesel V8         15.0  102782.106667  35066.014517  56646.34
# Motor 4.0 Turbo         19.0  106434.262632  20162.934641  60998.33
# Motor Diesel            21.0  107459.729048  30796.988909  54263.16
# Motor V6                16.0  109737.689375  28449.062835  54332.87
#
#                               25%         50%          75%        max
# ...

# %%
# contando os registros por tipo de motor
dataset['Motor'].value_counts()
# Out:
# Motor 1.0 8v             22
# Motor Diesel             21
# Motor 4.0 Turbo          19
# Motor Diesel V6          18
# Motor 3.0 32v            17
# Motor 5.0 V8 Bi-Turbo    17
# Motor V8                 17
# Motor V6                 16
# Motor Diesel V8          15
# Motor 2.0 16v            15
# Motor 1.8 16v            14
# Motor 2.4 Turbo           6
# Name: Motor, dtype: int64

# %%
# agrupando os registros por ano e calculando a Quilometragem Média
dataset.groupby(by = 'Ano')['Quilometragem'].mean()
# Out:
# Ano
# 1990    72083.666667
# 1991    47036.444444
# 1992    51283.000000
# 1993    55384.250000
# 1994    70260.777778
# 1995    71289.714286
# 1996    50926.100000
# 1997    71897.000000
# 1998    71828.000000
# 1999    39075.500000
# 2000    98921.000000
# 2001    69583.750000
# 2002    59268.545455
# 2003    56926.571429
# 2004    62735.800000
# 2005    58052.500000
# 2006    45569.750000
# 2007    59986.750000
# 2008    61647.833333
# 2009    48694.000000
# 2010    79227.333333
# 2011    53031.000000
# 2012    40817.500000
# 2013    39021.777778
# 2014    57461.500000
# 2015    61032.125000
# 2016    49972.000000
# 2017    74888.000000
# 2018    31999.000000
# Name: Quilometragem, dtype: float64

# %%
# agrupando os registros por ano e calculando o Valor Médio
dataset.groupby(by = 'Ano')['Valor'].mean()
# Out:
# Ano
# 1990     96116.206667
# 1991     93420.658889
# 1992     90670.667500
# 1993     93357.635000
# 1994     96623.326667
# 1995     86117.702857
# 1996     98619.528000
# 1997     96852.883333
# 1998     97801.913333
# 1999     98675.220000
# 2000    112101.906667
# 2001    105120.757500
# 2002     89327.512727
# 2003    111672.687143
# 2004     82253.320000
# 2005    117836.888333
# 2006     91200.577500
# 2007    101135.170000
# 2008    103123.380000
# 2009    110470.614286
# 2010     98001.035000
# 2011    106613.244000
# 2012     89212.192500
# 2013    105672.001111
# 2014     87228.613333
# 2015    103795.111250
# 2016    100531.173750
# 2017    109533.574286
# 2018     80452.258000
# Name: Valor, dtype: float64
